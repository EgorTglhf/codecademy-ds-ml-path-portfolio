# %% [markdown]
# # Life expectancy GDP

# %% [markdown]
# This is the second project on Codecademy Data Scientist: Machine Learning Career Path.
#
# The given by Codeacademy dataset has been stored in __all_data.csv__.
#
# Data has been taken from next sources:
# - GDP Source: [World Bank](https://data.worldbank.org/indicator/NY.GDP.MKTP.CD) national accounts data, and OECD National Accounts data files.
# - Life expectancy Data Source: [World Health Organization](http://apps.who.int/gho/data/node.main.688)
#
# This project aims to examine the potential strong correlation between a country's economic output and the life expectancy of its citizens. The objectives include data preparation, conducting an analysis using visualizations, and interpreting the study's findings.

# %% [markdown]
# # Load data

# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# First we import neсessary python libraries. To search for dependences between GDP and life expectancy load the datasets into DataFrames, what means we need Pandas. To evaluate and visualize our findings we may use Matplotlib and Seaborn as well.
#
# Then we load __all_data.csv__ and read first rows by `.head()` to take a first look.

# %%
df = pd.read_csv("all_data.csv")
df.head()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB

# %% [markdown]
# Checked info about our DataFrame we learned there are 96 records and 4 columns.

# %% [markdown]
# # Explore data

# %% [markdown]
# First let's learn more about the given data. Explore what values we have in the 'Country' and 'Year' columns.

# %%
print(df['Country'].unique())
print(df['Year'].unique())
# Out:
# ['Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe']
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015]

# %% [markdown]
# So here we have data from about 6 countries arranged from 2000 to 2015.

# %% [markdown]
# #### Small note about naming

# %% [markdown]
# We see that the third column has an absolutely descriptive name, but it will be not so comfortable to use such name in following analysis. So it would be better to rename the column to something shorter.

# %%
df = df.rename({"Life expectancy at birth (years)":"Expectation"}, axis = "columns")
df.head()
# Out:
#   Country  Year  Expectation           GDP
# 0   Chile  2000         77.3  7.786093e+10
# 1   Chile  2001         77.3  7.097992e+10
# 2   Chile  2002         77.8  6.973681e+10
# 3   Chile  2003         77.9  7.564346e+10
# 4   Chile  2004         78.0  9.921039e+10

# %% [markdown]
# # Time tendency

# %% [markdown]
# Let's look at indicators such as life expectancy and GDP over time by country.

# %% [markdown]
# #### Life expectancy

# %%
sns.lineplot(x='Year', y='Expectation', hue='Country', data=df)
plt.ylabel('Life expectancy at birth (years)')
plt.title('Life expectancy over time by countries')
plt.show()
plt.clf()

# %% [markdown]
# We can observe that it seems to have an increasing life expectancy tendency. More for Zimbabwe and less for others, but still. Also, we can note that Chile and Mexico have decreasing periods of life expectancy. But the plot scale for all countries in time doesn't allow us to recognize all the details. It will be more recognizable if we draw different plots for every country.

# %%
graphLifeExpectancy = sns.FacetGrid(df, col='Country', col_wrap=3, hue='Country', sharey=False)
graphLifeExpectancy.map(sns.lineplot, 'Year', 'Expectation').add_legend().set_axis_labels("Year","Life expectancy at birth (years)")
plt.show()
plt.clf()

# %% [markdown]
# Without doubt, we can say that there is an increase in life expectancy over time for every country from a given ones. Chile and Mexico have decreasing periods for several years until 2010, after which life expectancy starts growing again. Zimbabwe had a decreasing tendency before about 2004 and then started growing.

# %% [markdown]
# #### GDP

# %%
sns.lineplot(x='Year', y='GDP', hue='Country', data=df)
plt.ylabel('Gross domestic product (GDP) ')
plt.title('Gross domestic product (GDP) over time by countries')
plt.show()
plt.clf()

# %% [markdown]
# Here we also can observe that it seems to have an increasing GDP tendency. But not from all countries. Obviously, USA and China have an increasing GDP tendency, Germany and Mexico have but it's not so clear. And for Chile and Zimbabwe this is hardly distinguishable. Also, we can note that USA, Germany and Mexico have decreasing periods of GDP. But like in previous time the plot scale for all countries in time doesn't allow us to recognize all the details. It will be more recognizable if we draw different plots for every country.

# %%
graphGDP = sns.FacetGrid(df, col='Country', col_wrap=3, hue='Country', sharey=False)
graphGDP.map(sns.lineplot, 'Year', 'GDP').add_legend().set_axis_labels("Year", "GDP in Trillions of U.S. Dollars")
plt.show()
plt.clf()

# %% [markdown]
# Observing individual plots, we can clearly declare that every country has a positive GDP tendency and had more GDP in 2015 than in 2000. Also, we can note that sometime in 2008, Chile, Germany, Mexico and the USA started decreasing GDP but recovered and started growing again except Germany (It was the Great Recession). Interesting fact that the GDP of Zimbabwe decreased until about 2008 and started increasing that. China did not have any problems at all, only a slight decrease in growth rate.

# %% [markdown]
# # Correlation between GDP and life expectancy

# %% [markdown]
# Now it's time to look over the main question: is there a correlation between GDP and life expectancy?
#
# First let's take a look at scatter plot between these two indicators for every countries.

# %%
sns.scatterplot(x='Expectation', y='GDP', hue='Country', data=df)
plt.ylabel('Gross domestic product (GDP)')
plt.xlabel('Life expectancy at birth (years)')
plt.show()
plt.clf()

# %% [markdown]
# As we are already used to the plot scale, it is not too comfortable to distinguish the details for every country. Though we can say that there is visual correlation between the indicators for every country.
# So let's draw individual plots.

# %%
graphGDP = sns.FacetGrid(df, col='Country', col_wrap=3, hue='Country', sharey=False, sharex=False)
graphGDP.map(sns.scatterplot, 'Expectation', 'GDP').add_legend().set_axis_labels("Life expectancy at birth (years)", "Gross domestic product (GDP)")
plt.show()
plt.clf()

# %% [markdown]
# Observing individual plots, we can clearly declare that every country has a correlation between GDP and life expectancy. It is a question what exact type of relationship they have in every country, either exponential like China seems to have or linear like the USA seems to have, but the more GDP the more life expectance in every country.

# %% [markdown]
# # Average life expectancy

# %% [markdown]
# The next task is to find average life expectancy by country. First, let's make a new dataframe that will have a means of life expectancy for every country.

# %%
dfMeans = df.drop('Year', axis=1).groupby('Country').mean()

# %%
print(dfMeans)
# Out:
#                           Expectation           GDP
# Country
# Chile                        78.94375  1.697888e+11
# China                        74.26250  4.957714e+12
# Germany                      79.65625  3.094776e+12
# Mexico                       75.71875  9.766506e+11
# United States of America     78.06250  1.407500e+13
# Zimbabwe                     50.09375  9.062580e+09

# %% [markdown]
# Now we can create proper plots to show average indicators for countries.

# %%
sns.barplot(x='Expectation', y='Country', data=df)
plt.ylabel('Country')
plt.xlabel('Life expectancy at birth (years)')
plt.show()
plt.clf()

sns.barplot(x='GDP', y='Country', data=df)
plt.ylabel('Country')
plt.xlabel('GDP in Trillions of U.S. Dollars')
plt.show()
plt.clf()

# %% [markdown]
# As we can see, all countries except Zimbabwe have high life expectancy a more than 70 and values start from the middle of the 70s.

# %% [markdown]
# What about GDP, we clearly see that USA's GDP is much more than the GDP of other countries. Chile's GDP is hardly seen and Zimbabwe's GDP disappeared.

# %% [markdown]
# # Distribution

# %% [markdown]
# The last question we have is next: what do distributions of GDP and life expectancy look like?

# %%
plt.figure(figsize=(12,6))
ax1 = plt.subplot(1, 2, 1)
sns.histplot(df.GDP)
plt.xlabel("GDP in Trillions of U.S. Dollars");
ax2 = plt.subplot(1, 2, 2)
sns.histplot(df.Expectation)
plt.xlabel("Life expectancy at birth (years)");
plt.show()
plt.clf()

# %% [markdown]
# We can notice that GDP distribution is highly right-skewed. After an analysis, we may say that a small number of values on the right tail due to that no every country reach such high values and which has reached those move on.
#
#
# Life expectancy distribution is highly left-skewed. After an analysis, we may say the left tail belongs to rows in Zimbabwe and thus distorts the distribution.

# %% [markdown]
# Another method to show the distribution of a value for different sources is a combination of a swarm plot and a violin plot.

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(15, 5))
axes[0] = sns.violinplot(ax=axes[0], x=df.GDP, y=df.Country,color = "black")
axes[0] = sns.swarmplot(ax=axes[0], x=df.GDP, y=df.Country, hue=df.Country)
axes[0].legend([],[], frameon=False)
axes[0].set_xlabel("GDP in Trillions of U.S. Dollars")
axes[1] = sns.violinplot(ax=axes[1], x=df.Expectation, y=df.Country, color = "black")
axes[1] = sns.swarmplot(ax=axes[1], x=df.Expectation, y=df.Country, hue=df.Country)
axes[1].legend([],[], frameon=False)
axes[1].set_xlabel("Life expectancy at birth (years)");
plt.show()
plt.clf()

# %% [markdown]
# # Conclusions

# %% [markdown]
# During this project we were demonstrating data visualization skills and analyzing GDP and life expectancy for 6 given countries.
#
# By the end of the project, we have answers to the next questions:
# - Has life expectancy increased over time in the six nations?
#     - Yes, life expectancy increased over time for all given countries. Zimbabwe has the greatest increase.
# - Has GDP increased over time in the six nations?
#     - Yes, GDP has also increased for all given countries. China has the greatest increase.
# - Is there a correlation between GDP and life expectancy of a country?
#     - Yes, there is a positive correlation between GDP and life expectancy for given countries.
# - What is the average life expectancy in these nations?
#     - Average life expectancy starts from the middle of the 70s. Zimbabwe is an exclusion which has life expectancy that equals 50.
# - What is the distribution of that life expectancy?
#     - The life expectancy is left-skewed.
